# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
import pandas as pd

file_path = 'spw.xlsx'
df = pd.read_excel(file_path)

# %%
df = df[['TOWN', 'DISTRIBUTOR', 'NAME']].head(10000)
df['DISTRIBUTOR'] = df['DISTRIBUTOR'].astype(int)
df['TOWN'] = df['TOWN'].astype(int)
X = df[['DISTRIBUTOR', 'TOWN']]
y = df['NAME']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=15)

knn = KNeighborsClassifier(n_neighbors=11)

knn.fit(X_train, y_train)

predictions = knn.predict(X_test)

accuracy = knn.score(X_test, y_test)

# %%
print("Predictions:", predictions)
print("Accuracy:", accuracy)
# Out:
# Predictions: ['AFZAL' 'AL-HAMZA K.S' '786 Bakery' '786 K/S' '786 K/S' 'AL MEHRAN STORE'
#  'Qasim Cosmetics' 'ABDUL GHANI KRY' 'Abdul Rahman cabin' 'AL SYED STORE'
#  'BASHARAT G/S' '786-GS' 'Ahmed G/S' 'AL MEHRAN STORE' 'ASIF K/S'
#  'Abdul Jabbar k/s' 'AL MEHRAN STORE' 'ANMOL STORE' '786 Ch KS' '786-GS'
#  'Ali Mart' 'AL MADINA (BLK-A)' 'AL MEHRAN STORE' 'AL SYED' 'Ahmed G/S'
#  'AFZAL' 'A HAMEED K/S' 'ABBAS G/STORE' 'AL SYED STORE' 'Mian Store'
#  'AL MADINA (BLK-A)' 'ASHRAF SUPER STORE' 'AFZAL' 'AL MADINA G/S SK'
#  'AL MEHRAN STORE' 'AFZAL' 'AL MADINA (BLK-A)' 'ABDUL MAJEED K/S'
#  'A HAMEED K/S' 'ABBAS G/STORE' 'Aman Ullah GS' '786-GS' 'AL MEHRAN STORE'
#  'Akhtar Shah' 'ABDUL BAKI' 'AHMER STORE' 'AHMER STORE' 'Ahmed G/S'
#  'AHmed Store' 'Mian Store' 'DEWAN BAKERS' 'Mian Store' 'AHmed Store'
#  '786 Ch KS' 'AL-TAHIR M/S' 'AL MADINA (BLK-A)' 'AFZAL' 'AL MEHRAN STORE'
#  'Al Noor Bakers' 'ABO BAKAR GENRAL' 'AHMER STORE'
#  'Abdul Qayum Lon Merchant' 'ABDUL ISLAM K/S' '786 Ch KS'
#  'Abdul Rahman cabin' 'AL-TOFAIL G/S' 'HAJI G. MUHAMMAD K/STORE' '786 K/S'
#  'A2N  K/S' 'ASIF K/S' '786 K/S' 'AL HABEEB C/F' 'ABDUL MAJEED K/S'
#  'AL MEHRAN STORE' 'AHMER STORE' 'AFZAL' '786-GS' 'ANAS K.S AND G.S'
#  'ASHRAF SUPER STORE' 'Abid Hussain Shah' 'Mian Store' 'A2N  K/S'
#  'AAL E NABI BAKERS' '786-GS' 'Ahmed Medical' 'AHMER STORE'
#  'A.Aziz K/Store' 'AL SYED STORE' 'ABDUL ISLAM K/S' 'AL FAJAR STORE'
#  'A2N  K/S' 'ABID SHAHID' 'AL MEHRAN STORE' 'Abdul Rahman cabin'
#  'Bambol Masala' 'Abdul Jabbar k/s' 'AL MEHRAN STORE' 'Abrar K/S'
#  'AWAIS MEMON' 'Al-Riaz Store' 'ABDUL BAKI' 'ABDUL REHMAN KS'
#  'A.Aziz K/Store' '786 Ch KS' 'ABBAS G/STORE' 'Abdul Jabbar k/s'
#  '786 Ch KS' 'ADIL SHAH' 'Abbas G/s' '786 Ch KS' 'AL MADINA (BLK-A)'
#  'ABBAS K/S' 'ALLA DITTA KS' '786-GS' 'Abdul Jabbar k/s' 'Ameer Hamza K/s'
#  'Ahmed G/S' 'AL HAJWARY F/M' 'ABBAS K/S' 'A.Aziz K/Store'
#  'AL MADINA (BLK-A)' 'AHMER STORE' 'Mian Store' 'AL MEHRAN STORE'
#  'Abdul Qayum Lon Merchant' 'Azad' 'AL SYED STORE' 'A HAMEED K/S'
#  'AL MEHRAN STORE' 'ASIF G/S' 'AL FAJAR STORE' 'Abdul Jabbar k/s' 'AFZAL'
#  'AL FAJAR STORE' 'Ahmed G/S' 'Ahmed G/S' 'APEX PHARMACY' 'Mian Store'
#  'AFZAL' 'Mian Store' 'AL SYED' 'AL MEHRAN STORE'
#  'Abdul Qayum Lon Merchant' 'AL MAKKAH STORE' 'A2N  K/S'
#  'Akbar Hussain GS' '786 Ch KS' 'AHmed Store' 'Abdul Rahman cabin'
#  'AL HABEEB C/F' 'Commando k/s' 'AHMER STORE' 'AL SYED STORE'
#  'AHMER STORE' 'A2N  K/S' 'Abdual Rasheed K/S' 'AZAM' 'Mian Store'
#  'ABDUL GHANI KRY' 'AL AHMAD K/S' 'AL MADNI BAKERY' '786 Ch KS'
#  '786 Bakery' 'AL MADINA G/S SK' '786 K/S' 'AFZAL' 'Al-Riaz Store'
#  'AL MADINA (BLK-A)' 'Akbar Hussain GS' 'AL FAJAR STORE' '786-GS' 'AFZAL'
#  'ABDUL GHANI KRY' 'AKRAM BILAL' 'AL MADINA (BLK-A)' 'ANMOL STORE'
#  'A HAMEED K/S' 'ABDUL ISLAM K/S' 'Ahmad Ali K/S' 'AL FAJAR STORE'
#  'AB MAJEED ARAIN K/S' 'Abdul Qayum Lon Merchant' 'AL MEHRAN STORE'
#  'AL MEHRAN STORE' 'ABDUL GHANI KRY' 'Al Noor Bakers' 'A2N  K/S'
#  'Mian Store' 'ABBAS K/S' 'BABA G K.S' 'Mian Store' 'AL-TOFAIL G/S'
#  'AL MADINA (BLK-A)' '786-GS' 'ITIHAD G/S' 'ABBAS G/STORE'
#  'AL MEHRAN STORE' 'ABBAS G/STORE' 'AL MEHRAN STORE' 'AL MEHRAN STORE'
#  'AL HABEEB C/F' 'ANAS K.S AND G.S' 'A2N  K/S' 'ABBAS G/STORE'
#  'Mian Store' '786 Ch KS' 'AL MAKKAH STORE' '786 Bakery' 'ABDUL GHANI KRY'
#  'ABDUL QADEER' 'AHMER STORE' 'AL FAJAR STORE' 'AL REHMAN' '786-GS'
#  'ARIF WS' '786 Ch KS' 'AARIF K/STORE' 'AAL E NABI BAKERS' '786 Ch KS'
#  'AL SYED STORE' 'AHMER STORE' 'Aman Ullah GS' 'Ahmed G/S' 'AHMER STORE'
#  'ABID SHAHID' 'AL SYED STORE' '786 Ch KS' '786 K/S' 'Akhtar Shah'
#  'AL MEHRAN STORE' 'ASIF K/S' 'ABBASI G/S' 'ABDUL GHANI KRY'
#  'APEX PHARMACY' 'Mian Store' 'AL MADINA (BLK-A)' '786 Ch KS' 'Ahmed G/S'
#  'Asif K/s' 'Abdul Qayum Lon Merchant' 'AL FAJAR STORE' 'AFZAL'
#  'ANMOL STORE' 'Abdul Jabbar k/s' 'ABDUL MAJEED K/S' 'AFZAL' 'Ahmed G/S'
#  '786-GS' 'HAJI G. MUHAMMAD K/STORE' 'ABDULAH KAMBOH G/S' 'Akhtar Shah'
#  'AL MEHRAN STORE' 'AL SYED STORE' 'A2N  K/S' 'AHMER STORE' '786 Ch KS'
#  'ABID SHAHID' 'AL REHMAN' 'ALLA DITTA KS' 'Al-Riaz Store' 'AFZAL'
#  'AL MEHRAN STORE' 'ASIF K/S' '786 Ch KS' '786-GS' 'ANAS K.S AND G.S'
#  'Akhtar Shah' 'ABDUL GHANI KRY' 'A HAMEED K/S' 'AHMER STORE'
#  'AL MEHRAN STORE' 'AZAM' 'Azad' '786-GS' 'A.Aziz K/Store'
#  'ABDUL MAJEED K/S' 'Afaq G/S' '786 S/S~  Gulstan Market' 'AL SYED STORE'
#  'Al-Riaz Store' '786 Bakery' 'Al-Riaz Store' 'ABDUL GHANI KRY'
#  'ANMOL STORE' 'Mian Store' 'AL EMANI K/S' 'AFZAL' 'Mian Store'
#  'ABDULAH KAMBOH G/S' 'AL MADINA G/S SK' 'AFZAL' 'ABDUL REHMAN KS'
#  'AL-TOFAIL G/S' 'A2N  K/S' 'AHMER STORE' 'ASIF K/S' 'AL MADINA (BLK-A)'
#  'AKHTIYAR AHMED' 'ITIHAD G/S' 'Abbasi G/S' 'Abdul Qayum Lon Merchant'
#  'ABDULAH KAMBOH G/S' 'A HAMEED K/S' 'AL SYED STORE' '786 Ch KS'
#  'AB MAJEED ARAIN K/S' '786-GS' 'Al Hilal Pharmacy' 'AFZAL' '786 Ch KS'
#  'AL HAJWARY F/M' 'AL MADINA (BLK-A)' 'A HAMEED K/S' 'AL MADINA KS'
#  'ASIF K/S' 'AFZAL' 'AL MEHRAN STORE' 'ALTAF CONFECTIONARY' '786 Ch KS'
#  'AL-QASIM K/S' 'AL MEHRAN STORE' 'AHMER STORE' 'Ahmed G/S' 'A2N  K/S'
#  'Mian Store' 'AL FAJAR STORE' 'Mian Store' 'Ahmed G/S' 'AL MEHRAN STORE'
#  'AL-QASIM K/S' 'ASIF G/S' 'ABDUL GHANI KRY' 'AL MEHRAN STORE'
#  'Al Noor Bakers' '786 Ch KS' 'ABID SHAHID' 'ANEEL KUMAR' 'AL SYED STORE'
#  'AL MEHRAN STORE' 'AARIF K/STORE' 'AL REHMAN' 'Abdul Qayum Lon Merchant'
#  '786 K/S' 'AL MADINA G/S SK' 'ASIF K/S' '786 Ch KS' 'ALLA DITTA KS'
#  'ABDUL GHANI KRY' 'AL MADINA G/S SK' 'AHMER STORE' 'ABID SHAHID'
#  'Abdul Jabbar k/s' 'AL SYED STORE' 'AHMER STORE' 'Abdul Hadi Soomro'
#  'ASIF G/S' 'A2N  K/S' 'Al-Riaz Store' 'ABDUL GHAFFAR K/S'
#  'AL MADINA G/S SK' '786-GS' '786-GS' 'ABDUL GHANI KRY' 'ANMOL STORE'
#  'AFZAL' '786 Ch KS' 'A2N  K/S' 'ABDUL QADEER' 'Ahmed G/S' 'A2N  K/S'
#  'AL SYED STORE' 'AL MEHRAN STORE' 'AFZAL' 'Mian Store'
#  'Al Hilal Pharmacy' '786 Ch KS' 'ADIL BAIG' 'Abrar K/S' 'AZAM'
#  '786 Ch KS' 'ABDUL GHANI KRY' 'AL SYED STORE' 'Ahmed Ali K/S'
#  'Akhtar Shah' 'ARIF WS' 'AHMER STORE' 'A2N  K/S' 'AHMED MOHAMMAD K.S'
#  'A2N  K/S' 'AL SYED STORE' 'A HAMEED K/S' 'ABBASI G/S' 'AL MEHRAN STORE'
#  'Insaf G/S' 'AHMER STORE' 'AL MEHRAN STORE' '786 Ch KS' 'AFZAL' 'AFZAL'
#  'AHmed Store' 'AZAM' 'ASIF K/S' 'AL-MADINA G/S' 'AFZAL' 'AL FAJAR STORE'
#  'ABDUL GHANI KRY' 'Abdul Jabbar k/s' 'AL SYED STORE' 'ALLA DITTA KS'
#  'AL MADINA G/S SK' 'AL-QASIM K/S' 'A HAMEED K/S' 'Mian Store'
#  '786 S/S~  Gulstan Market' 'AL MEHRAN STORE' 'ABDUL MAJEED K/S'
#  'Mian Store' 'AL AHMAD K/S' 'ASIF K/S' 'OSHAQUE ALI' 'Mian Store'
#  'Asif K/s' 'ABDUL GHAFFAR K/S' 'AL MEHRAN STORE' 'AHMER STORE'
#  'ADIL SHAH' 'AARIF K/STORE' '786 Bakery' 'A HAMEED K/S' 'A.Aziz K/Store'
#  'AL SYED STORE' 'AL SYED STORE' 'Al Noor Bakers' 'AL MADINA KS'
#  '786 Ch KS' 'AL MADINA (BLK-A)' 'Abdul Rahman cabin' '786 Ch KS'
#  'A.Aziz K/Store' 'AL SYED STORE' 'Abdul Jabbar k/s' 'ABDULAH KAMBOH G/S'
#  'A.Aziz K/Store' 'AFZAL' 'Al-Riaz Store' 'DEWAN BAKERS'
#  'ABDUL MAJEED K/S' '786-GS' 'Abbasi G/S' 'AL MEHRAN STORE' 'SINDHU G/S'
#  'AHMER STORE' '786 Bakery' 'A2N  K/S' '786-GS' 'AHMER STORE' 'Azad'
#  'ALI HAIDER' 'A2N  K/S' 'A.B Butt K/s' 'AHMER STORE' 'Ahmed G/S'
#  '786 Ch KS' 'AL MEHRAN STORE' 'ABBAS K/S' 'A2N  K/S' 'ABID SHAHID'
#  'Abdul Jabbar k/s' 'ABDULAH KAMBOH G/S' 'AL SYED STORE' 'AL FAJAR STORE'
#  'AL-SHAIKH K/S' 'Naveed Store' 'Mian Store' 'A. QADEER K/S'
#  'AL MADINA G/S SK' 'SINDHU G/S' 'AL MEHRAN STORE' 'Ahmad Ali K/S'
#  'A2N  K/S' 'AL MEHRAN STORE' 'Al-Riaz Store' '786 Ch KS' 'Al-Riaz Store'
#  'A2N  K/S' 'Mian Store' 'Jani keryana store' 'Abdul Jabbar k/s' 'AFZAL'
#  'AL MADINA (BLK-A)' '786-GS' 'AL MEHRAN STORE' 'ADNAN KARYANA' 'ASIF K/S'
#  'Abdul Jabbar k/s' 'A2N  K/S' 'AL MAKKAH STORE' 'Abdul Aziz'
#  'ADEEL ALI ARAIN KS' 'A2N  K/S' 'Abdul Hadi Soomro' 'AZAN' 'A2N  K/S'
#  'AZAN' 'Jani keryana store' 'ABDULAH KAMBOH G/S' 'AFZAL' 'A2N  K/S'
#  'ABID SHAHID' 'Akbar Hussain GS' 'AL SYED STORE' 'Afaq G/S'
#  'Abdul Jabbar k/s' 'AL HABEEB C/F' 'ABDUL GHANI KRY' 'ABID SHAHID'
#  'AL-SAJJAD K/S' 'Al-Riaz Store' 'Asif K/s' 'AL MADINA (BLK-A)' 'A2N  K/S'
#  'AL MEHRAN STORE' 'AL HABEEB C/F' 'AL MADINA G/S SK' '786-GS'
#  'AL-SAJJAD K/S' 'AFZAL' 'AL MADINA (BLK-A)' 'ANMOL STORE' '786-GS'
#  'A.Aziz K/Store' '786-GS' 'AL SYED STORE' 'AL MADNI BAKERY'
#  'ALTAF CONFECTIONARY' 'Akhtar Shah' 'ABID SHAHID' 'Mian Store'
#  'Abbasi G/S' 'Abrar K/S' 'Al-Riaz Store' 'AL-TAHIR M/S' 'AL SYED'
#  'ABBAS G/STORE' 'ADNAN S/W' 'AL SYED STORE' 'AL MEHRAN STORE' 'ADIL BAIG'
#  'A2N  K/S' 'Mian Store' 'AL MAKKAH STORE' 'AKHTIYAR AHMED'
#  'ABDUL KHALIQ G/S' 'AL MADINA G/S SK' 'Abdul Jabbar k/s' 'ABID SHAHID'
#  '786 Ch KS' 'A2N  K/S' 'AJ MARTS' 'Mian Store' 'Mian Store'
#  'AL FAJAR STORE' '786 Ch KS' 'AHmed Store' 'A2N  K/S' '786 Ch KS'
#  'ADIL BAIG' 'Jani keryana store' 'AL MADINA (BLK-A)' 'AHMER STORE'
#  'Abdul Rahman cabin' 'Mian Store' 'AL HAJWARY F/M' 'ABDUL GHAFFAR K/S'
#  'AL-NAJAF G/S' 'Ahmed G/S' 'A.Aziz K/Store' 'AFZAL' 'AL FAJAR STORE'
#  '786 Karyana Store' 'A2N  K/S' 'ABID SHAHID' 'Mian Store' '786 Ch KS'
#  'AL MADINA G/S SK' 'ABDULAH KAMBOH G/S' 'AL MEHRAN STORE' 'Al-Riaz Store'
#  'AL SYED STORE' 'AFZAL' 'Mian Store' 'ANMOL STORE' 'AL SYED STORE'
#  'Abdul Qayum Lon Merchant' 'Ahmed G/S' 'ABDUL GHANI KRY' 'AL FAJAR STORE'
#  'AFZAL' 'AL MADINA (BLK-A)' 'AFZAL' '786 Ch KS' 'Al-Riaz Store' 'AFZAL'
#  'A2N  K/S' 'AL SYED STORE' 'A2N  K/S' 'Adil Medical' 'A2N  K/S'
#  '786 Ch KS' 'ABDUL GHANI KRY' '786 Ch KS' '786 Ch KS' 'AL MADINA G/S SK'
#  'AL SYED STORE' '786-GS' 'ABBAS K/S' 'AL MADINA G/S SK' 'Ahmed G/S'
#  'AFZAL' 'Abdul Rahman cabin' 'ABDUL MAJEED K/S' 'AFZAL K/S'
#  'AARIF K/STORE' 'Afsham Store' '786 Ch KS' 'AL MADINA G/S SK'
#  'AL MADINA G/S SK' 'ABBAS K/S' 'A2N  K/S' 'AB MAJEED ARAIN K/S'
#  'AL MEHRAN STORE' 'A2N  K/S' '786 K/S' 'AFZAL' 'ABID SHAHID' 'ASIF K/S'
#  'ABDUL GHAFFAR K/S' 'A2N  K/S' 'A2N  K/S' 'AL MAKKAH STORE'
#  'Abdul Rahman cabin' 'ADIL SHAH' '786 K/S' 'AHMER STORE' 'Aamir K/s'
#  'ADIL BAIG' 'ABDUL GHANI KRY' 'AL SYED STORE' 'ANMOL STORE'
#  'ALTAF CONFECTIONARY' 'Mian Store' 'APEX PHARMACY' '786 K/S' 'AZAN'
#  'Akhtar Shah' 'AL MADINA G/S SK' 'Mian Store' 'AFZAL' 'AL-SAJJAD K/S'
#  'ABDUL ISLAM K/S' 'AL MEHRAN STORE' 'Abdul Qayum Lon Merchant'
#  'AHmed Store' 'A2N  K/S' 'ABDUL MAJEED K/S' 'Abdul Qayum Lon Merchant'
#  'Asif K/s' 'AZAN' 'ANMOL STORE' 'AL FAJAR STORE' 'ASIF K/S'
#  'AL FAJAR STORE' 'Aman Ullah GS' 'Abdullah k.s' 'AL FAJAR STORE'
#  'ABDUL GHANI KRY' 'A2N  K/S' 'A2N  K/S' 'Abbasi G/S' 'AFZAL' 'ASIF K/S'
#  'ABDUL REHMAN KS' '786-GS' 'ABDUL QADEER' 'ABDUL GHANI KRY' 'Asif K/s'
#  'AL FAJAR STORE' 'AL MEHRAN STORE' 'ADIL SHAH' 'A.Aziz K/Store'
#  'ABDUL GHAFFAR K/S' 'AL MADINA G/S SK' '786 Ch KS' 'ALI HAIDER'
#  'A2N  K/S' 'AL FAJAR STORE' 'AL MEHRAN STORE' 'AFZAL' 'ITIHAD G/S'
#  'AL MADINA KS' 'AL MADINA (BLK-A)' 'ABDUL MAJEED K/S' 'Mian Store'
#  'AFZAL K/S' 'AL-SAJJAD K/S' 'AHMER STORE' 'ABID SHAHID' 'Al-Riaz Store'
#  'A2N  K/S' 'A2N  K/S' 'A2N  K/S' 'Abdul Qayum Lon Merchant' 'Ahmed G/S'
#  '786-GS' 'AWAIS MEMON' 'AL FAJAR STORE' 'AL MADINA (BLK-A)' '786 Ch KS'
#  'AL MEHRAN STORE' 'AL HABEEB C/F' 'A HAMEED K/S' '786 Ch KS'
#  'AL MEHRAN STORE' 'AL-HAMZA K.S' 'Al-Riaz Store' 'AL-SHAIKH K/S'
#  'AL SYED' 'AL SYED STORE' 'AHmed Store' 'AL-HAMZA K.S' 'Ahmed G/S'
#  'ALI GOHAR' 'ASIF K/S' '786 Ch KS' 'AL HAJWARY F/M' 'AL MEHRAN STORE'
#  'AL MADINA (BLK-A)' 'Mian Store' 'AL MADINA (BLK-A)' 'Bambol Masala'
#  'Abbas G/s' 'AL MEHRAN STORE' 'Abid Hussain Shah' 'AL MADINA (BLK-A)'
#  'AFZAL' '786 ks' 'AL-TAHIR M/S' 'AL MADINA G/S SK' '786 Ch KS'
#  'AL MEHRAN STORE' 'Abdul Qayum Lon Merchant' 'ALLA DITTA KS'
#  'AL MEHRAN STORE' 'AL MEHRAN STORE' 'Abdul Rahman cabin'
#  'ABDUL GHANI KRY' 'AL MADINA G/S SK' '786-GS' '786-GS' '786 Ch KS'
#  'ADIL BAIG' 'Afsham Store' '786 Ch KS' 'AAL E NABI BAKERS' 'Mian Store'
#  'A HAMEED K/S' 'AL-HAMZA K.S' 'DEWAN BAKERS' 'ABDUL GHAFFAR K/S'
#  'A2N  K/S' 'Abdul Rahman cabin' 'AL MADINA (BLK-A)' 'Adil Medical'
#  'A.Aziz K/Store' 'AL MEHRAN STORE' 'AHmed Store' 'A HAMEED K/S'
#  'ALLA DITTA KS' 'Insaf G/S' 'AL HASEEB G.S' 'Asif K/s' 'AL MADINA G/S SK'
#  'AL HABEEB C/F' 'ADIL BAIG' 'A HAMEED K/S' 'Afaq G/S' 'Al-Riaz Store'
#  'AL SYED STORE' 'ALI HAIDER' '786 Ch KS' 'Abdul Hadi Soomro' 'Asif K/s'
#  'Ahmed G/S' 'Ab. Majeed' 'Al-Riaz Store' 'A2N  K/S' 'AL HASEEB G.S'
#  'AL SYED STORE' 'AFZAL' 'Mian Store' 'AHmed Store' 'ANMOL STORE'
#  'Mian Store' 'Abdul Jabbar k/s' 'Ahmed G/S' 'Ahmed G/S' 'Ahmed G/S'
#  'AHMER STORE' '786-GS' 'Akhtar Shah' 'ADIL BAIG' '786-GS' '786 K/S'
#  'A2N  K/S' 'AFZAL' 'AL MADINA (BLK-A)' 'AL SYED STORE' 'AL-SHAIKH K/S'
#  'AL-TAHIR M/S' 'AL SYED STORE' 'AL SYED' 'Aman Ullah GS' 'AL SYED STORE'
#  'A.Aziz K/Store' 'ABBAS G/STORE' 'AL MADINA G/S SK' 'Mian Store'
#  'A2N  K/S' 'Ahmed G/S' 'ABBAS G/STORE' 'AL-QASIM K/S' 'AL MADINA (BLK-A)'
#  'A. QADEER K/S' 'AL FAJAR STORE' 'Abrar K/S' 'Mian Store'
#  'AL MADNI BAKERY' '786-GS' '786 Ch KS' 'AL REHMAN' 'Mian Store'
#  'AL SHAREEF K/S' 'AL MEHRAN STORE' 'AL MEHRAN STORE' 'AL FAJAR STORE'
#  'AL HABEEB C/F' 'A.Aziz K/Store' 'Asif K/s' '786 Ch KS'
#  'AL MADINA G/S SK' 'AFZAL K/S' 'ANMOL STORE' 'ITIHAD G/S' 'Ahmed G/S'
#  'AHmed Store' 'ABID SHAHID' 'Amjad Trader' 'Ahmed G/S' 'ABDUL GHANI KRY'
#  'ABDUL GHANI KRY' '786-GS' 'Akhtar Shah' 'AKRAM BILAL' '786 Ch KS'
#  '786 K/S' 'AL SYED STORE' 'AL-SAJJAD K/S' 'Mian Store' 'AFZAL'
#  'AHMER STORE' 'AL SYED STORE' 'ALI HAIDER' 'AFZAL' 'ABDULAH KAMBOH G/S'
#  'OSHAQUE ALI' 'AL SYED STORE' 'Abdul Jabbar k/s' 'AHMER STORE'
#  '786 Ch KS' '786 K/S' 'ABID SHAHID' 'Ahmed G/S' 'ABDUL GHANI KRY'
#  'AL SYED STORE' 'AL MADINA (BLK-A)' 'Ahmed G/S' 'AL MEHRAN STORE'
#  'ABBAS  K.S' '786 Ch KS' 'A2N  K/S' 'ARIF WS' 'Mian Store' 'ABID SHAHID'
#  'Mian Store' 'Abdul Jabbar k/s' '786 Ch KS' 'AFZAL' 'Al-Riaz Store'
#  'AFZAL' 'Al-Riaz Store' 'AJ MARTS' 'AL-TOFAIL G/S' '786-GS'
#  'ABDUL GHANI KRY' 'Abdul Jabbar k/s' '786 Ch KS' 'AL MEHRAN STORE'
#  'Asif K/s' 'A2N  K/S' 'AHMER STORE' 'Mian Store' 'Insaf G/S' 'AJ MARTS'
#  'AL MADINA (BLK-A)' 'Al-Riaz Store' 'AZAM' 'Mian Store' '786 Ch KS'
#  'Abdul Jabbar k/s' 'A2N  K/S' 'AHMER STORE' 'A2N  K/S' 'AL FAJAR STORE'
#  'AFZAL' 'FARHAN COSMETICS' 'Al-Riaz Store' 'AL-QASIM K/S'
#  'ABDULAH KAMBOH G/S' 'Mian Store' 'AZAM' 'Mian Store' 'DEWAN BAKERS'
#  'ABDUL GHANI KRY' 'AL MADINA KS' 'ABBAS G/STORE'
#  'Abdul Qayum Lon Merchant' 'AHMER STORE' 'AL REHMAN' 'Afaq G/S' 'AFZAL'
#  'AL-HAMZA K.S' 'AL MEHRAN STORE' '786-GS' 'ASIF K/S'
#  'AL-Hamd cold Corner' 'Amjad Trader' 'AL MADINA (BLK-A)' 'Mian Store'
#  'A2N  K/S' 'A2N  K/S' 'Abbasi G/S' 'AL SYED STORE' 'AFZAL'
#  'AL MADNI BAKERY' 'ASIF K/S' 'Al Rahim K/S' 'Mian Store' 'AL FAJAR STORE'
#  'AL REHMAN' '786 K/S' 'ABDUL REHMAN KS' 'AHMER STORE' 'AFZAL'
#  'A.Aziz K/Store' '786 Ch KS' 'AL HABEEB C/F' '786 Ch KS'
#  'ABDUL ISLAM K/S' '786 Ch KS' 'ALI HAIDER' 'AL-TOFAIL G/S'
#  'AL MAKKAH STORE' 'ABDUL GHANI KRY' 'A HAMEED K/S' 'Jani keryana store'
#  '786-GS' '786 Bakery' 'ABBAS K/S' 'AFZAL' 'Mian Store' 'AL MAKKAH STORE'
#  'Ahmed G/S' 'AFZAL' '786-GS' 'Ahmed G/S' 'AL MADINA G/S SK' 'Asif K/s'
#  'AHmed Store' 'Jani keryana store' 'AFZAL' 'AHMER STORE' 'AL SHAREEF K/S'
#  'ABDUL GHANI KRY' 'ASIF K/S' 'AFZAL' 'ABO BAKAR GENRAL' 'Al-Riaz Store'
#  'Mian Store' 'Mian Store' 'AHMER STORE']
# Accuracy: 0.001
