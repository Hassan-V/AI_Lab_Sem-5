# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
import pandas as pd

file_path = 'spw.xlsx'
df = pd.read_excel(file_path)

# %%
df = df[['TOWN', 'DISTRIBUTOR', 'NAME']].head(10000)
df['DISTRIBUTOR'] = df['DISTRIBUTOR'].astype(int)
df['TOWN'] = df['TOWN'].astype(int)
X = df[['DISTRIBUTOR', 'TOWN']]
y = df['NAME']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

knn = KNeighborsClassifier(n_neighbors=11)

knn.fit(X_train, y_train)

predictions = knn.predict(X_test)

accuracy = knn.score(X_test, y_test)

# %%
print("Predictions:", predictions)
print("Accuracy:", accuracy)
# Out:
# Predictions: ['Abdul Karim Confectionary' 'AL MADINA K/S' 'AL-MADINA STORE'
#  '786 Bakery' 'AL-MADINA STORE' 'AL-MADINA STORE' '786 Bakery'
#  'ABDULLAH G/S' 'AFRIDI' 'AL-MADINA STORE' '786 Store' 'AL-MADINA STORE'
#  'AL-MADINA STORE' 'AHAMED K/S' 'AL MADINA K/S' 'AL MADINA K/S'
#  'AL GHANI SWEETS' 'ABDULLAH G/S' 'Aneel K/S' 'ABDUL WAHEED K/S'
#  'Al Madni K/S' 'AKHTAR K/S' 'AL-MADINA STORE' 'AL GHANI SWEETS'
#  'A.M Traders' 'AFRIDI' 'AL-MADINA STORE' 'AL-MADINA STORE' 'AFRIDI'
#  'ABDULLAH G/S' 'AHAMED K/S' 'Al Madni K/S' 'Al Madni K/S' 'AFTAB St'
#  'AL-MADINA STORE' 'AL MADINA K/S' 'AKHTAR K/S' 'AL-MADINA STORE'
#  'AL-MADINA STORE' 'AL MADINA K/S' 'ABDULLAH G/S' 'JHOLAYLAL'
#  'AL MADINA K/S' 'AHAMED K/S' 'Asad K/S' 'ABDULLAH G/S' 'AHAMED K/S'
#  'AHAMED K/S' 'ABDUL BAKI' 'AKHTAR K/S' '786 Store' 'ASLAM GEN. STORE.'
#  'AL Umair Store' 'AL MADINA K/S' 'Al Madni K/S' 'AHAMED K/S'
#  'AL-MADINA STORE' 'AHAMED K/S' 'AL-MADINA STORE' 'ASLAM GEN. STORE.'
#  'AHUJA M/S' 'Al Madni K/S' 'Asad K/S' 'AL-MADINA STORE'
#  'A ONE Masallah jat' 'AL-MADINA STORE' 'AL-MADINA STORE' 'Asad K/S'
#  'ABDULLAH G/S' 'Asad K/S' 'ARSHAD K.S' 'AL MADINA K/S' 'Asad K/S'
#  'AL-MADINA STORE' 'AFRIDI' 'ASLAM GEN. STORE.' 'Asad K/S' 'Al Madni K/S'
#  'AL MADINA K/S' 'ARSHAD K.S' 'ABDUL BAKI' 'ABDULLAH G/S' 'AL Umair Store'
#  'AHAMED K/S' 'Al Madni K/S' 'AHUJA M/S' 'AHAMED K/S' 'AHAMED K/S'
#  'ASLAM GEN. STORE.' 'Aneel K/S' 'AHAMED K/S' 'ABDULLAH G/S'
#  'AL MADINA K/S' 'ASLAM GEN. STORE.' 'AL-MADINA STORE' 'BAQIR G/S'
#  'ABDULLAH G/S' 'AL-MADINA STORE' 'AL Umair Store' 'ABDUL WAHEED K/S'
#  'Al Madni K/S' 'AL-MADINA STORE' 'AL MADINA K/S' 'Asad K/S'
#  'ABDUL WAHEED K/S' 'AL AHMAD K/S' 'AHAMED K/S' 'ABDUL WAHEED K/S'
#  'AHAMED K/S' 'Al Madni K/S' 'AHAMED K/S' 'ARSHAD K.S' 'AL-MADINA STORE'
#  'Abid Cosmetic' 'AHAMED K/S' 'ASLAM GEN. STORE.' 'Aijaz Shaikh'
#  'AL-MADINA STORE' 'AL MADINA K/S' 'AMEET K/S' 'Asad K/S'
#  'AL-MADINA STORE' 'AL-MADINA STORE' 'Al Madni K/S' 'ASLAM GEN. STORE.'
#  'AL Umair Store' 'ABDULLAH G/S' 'AFRIDI' 'ABBASI G/S' 'AL MADINA K/S'
#  'Abdul Karim Confectionary' 'JHOLAYLAL' 'Al Madni K/S' 'AHAMED K/S'
#  'ABDULLAH G/S' 'AL-MADINA STORE' 'AL-MADINA STORE' 'Aalam Khan K.S'
#  'AHAMED K/S' 'ABDULLAH G/S' 'AL-MADINA STORE' 'AL MADINA K/S'
#  'AHAMED K/S' '786 Bakery' 'Asad K/S' '786 Bakery' 'AHAMED K/S'
#  'AYAN STORE 2' 'AL MADINA K/S' 'ABDULLAH G/S' 'AHAMED K/S'
#  'AL-MADINA STORE' 'AHAMED K/S' 'AL-MADINA STORE' 'AL MADINA K/S'
#  'AHUJA M/S' 'AHAMED K/S' 'Asad K/S' 'AHAMED K/S' 'ASHRAF GS'
#  'Al Madni K/S' 'AHUJA M/S' 'ASLAM GEN. STORE.' 'AL-MADINA STORE'
#  'AL-MADINA STORE' 'AHUJA M/S' 'ABDULLAH G/S' 'AL-MADINA STORE'
#  'AL MADINA K/S' 'AHAMED K/S' 'AL-MADINA STORE' 'Al Madni K/S'
#  'Aalam Khan K.S' 'A.M Traders' 'AL MADINA K/S' 'AL-MADINA STORE'
#  'Al Madni K/S' 'AL-MADINA STORE' 'Al Madni K/S' 'AL AHMAD K/S'
#  'AL-MADINA STORE' 'Abid Cosmetic' 'ARSHAD K.S' 'AL-MADINA STORE'
#  'ABDULLAH G/S' 'Al Madni K/S' 'A.M Traders' 'AHUJA M/S' 'AL-MADINA STORE'
#  'ABBASI G/S' 'Al Madni K/S' 'ASLAM GEN. STORE.' 'AL Umair Store'
#  'ASLAM GEN. STORE.' 'ABDULLAH G/S' 'ABDULLAH G/S' 'AL-MADINA STORE'
#  'ABDULLAH G/S' 'AHAMED K/S' 'AMEET K/S' 'A.M Traders' 'AHAMED K/S'
#  'ABDULLAH G/S' 'ABDULLAH G/S' 'AL MADINA K/S' 'ABDUL WAHEED K/S'
#  'AMEET K/S' 'AL-MADINA STORE' 'AL-MADINA STORE' 'AFRIDI' 'AHAMED K/S'
#  'AHUJA M/S' 'A Ghaffar Chachar K/s' 'AFRIDI' 'AHAMED K/S' 'ASHRAF GS'
#  'AL-MADINA STORE' 'AL MADINA K/S' 'ABDUL WAHEED K/S' 'AL-MADINA STORE'
#  'AHAMED K/S' 'AFRIDI' 'AHAMED K/S' 'Abdul Karim Confectionary'
#  'AHAMED K/S' 'AL-MADINA STORE' 'AL MADINA K/S' 'AFRIDI' 'AL GHANI SWEETS'
#  'ASLAM GEN. STORE.' 'Dehleez K/S' 'ASLAM GEN. STORE.' 'AFZAL HUSSIAN K/S'
#  '786 K/S' 'Al Madni K/S' 'ABDUL WAHEED K/S' 'AL-MADINA STORE'
#  'AHAMED K/S' 'AL-MADINA STORE' 'AHAMED K/S' 'Al Madni K/S' 'Asad K/S'
#  'Al Madni K/S' '786 Bakery' 'Asad K/S' 'ABDULLAH G/S' '786 Store'
#  'Dehleez K/S' 'ABDULLAH G/S' 'AL-MADINA STORE' 'AL-MADINA STORE'
#  'AL MADINA K/S' 'AL-MADINA STORE' 'AHAMED K/S' 'AL Umair Store'
#  'AL-MADINA STORE' 'Al Madni K/S' 'AHAMED K/S' 'Aijaz Shaikh'
#  'AL-MADINA STORE' 'ABDULLAH G/S' 'ABDUL WAHEED K/S' 'ABDULLAH G/S'
#  'ARSHAD K.S' 'AL-MADINA STORE' 'A-lMejar Super Store' 'AL MADINA K/S'
#  'ABDULLAH G/S' 'ABDULLAH G/S' 'AL-MADINA STORE' 'AL-MADINA STORE'
#  'A ONE Masallah jat' 'Al Madni K/S' 'AL Umair Store' 'A ONE Masallah jat'
#  'A ONE Masallah jat' 'AHAMED K/S' 'AL MADINA K/S' 'AL Umair Store'
#  'ASLAM GEN. STORE.' 'AL-MADINA STORE' 'AL AHMAD K/S' '786 Bakery'
#  'AL Umair Store' 'AL-MADINA STORE' 'AFRIDI' 'ASLAM GEN. STORE.'
#  'AFTAB St' 'ABDULLAH G/S' 'ABDULLAH G/S' 'Agha G/s' 'ARSHAD K.S'
#  'Asad K/S' 'ALI WARIS K/S' '786 Bakery' 'ASHRAF GS' 'ABDULLAH G/S'
#  'Abid Cosmetic' 'Abdul Karim Confectionary' 'AL MADINA K/S' 'AHAMED K/S'
#  'ABDULLAH G/S' 'ALI WARIS K/S' 'AHAMED K/S' 'Al Madni K/S'
#  'ALI WARIS K/S' 'AL-MADINA STORE' 'AL-MADINA STORE' 'AHAMED K/S'
#  'ABDULLAH G/S' 'ABBASI G/S' 'Aneel K/S' 'AL-MADINA STORE'
#  'AL-MADINA STORE' 'AHMAD G/S' 'AFTAB St' '786 K/S' 'Asad K/S'
#  'AHAMED K/S' 'AHMAD G/S' 'ABDULLAH G/S' 'Anayat K/s' 'ABDULLAH G/S'
#  'AL MADINA K/S' 'AL-MADINA STORE' 'AHAMED K/S' 'JHOLAYLAL' 'ABDULLAH G/S'
#  'ARSHAD K.S' 'AHAMED K/S' 'ASLAM GEN. STORE.' 'AHAMED K/S'
#  'AL Umair Store' 'AHAMED K/S' 'ABDUL WAHEED K/S' 'AHAMED K/S'
#  'AL MADINA K/S' 'AHUJA M/S' 'ABBASI G/S' 'ABDULLAH G/S' 'Asad K/S'
#  'ASLAM GEN. STORE.' 'AL GHANI SWEETS' 'AHUJA M/S' 'Al Madni K/S'
#  'Aijaz Shaikh' 'AFZAL HUSSIAN K/S' 'Abid Cosmetic' 'Asad K/S'
#  'AL-MADINA STORE' 'ABDULLAH G/S' 'AHAMED K/S' 'AHUJA M/S'
#  'Chaudhary Medical Store' 'ABDULLAH G/S' 'Al Madni K/S' 'AHUJA M/S'
#  '786 Bakery' 'AMEET K/S' 'Agha G/s' '786 Bakery' 'ASLAM GEN. STORE.'
#  'AFRIDI' 'AFRIDI' 'Qasim Cosmetics' 'AHAMED K/S' 'Al Madni K/S'
#  'AYAN STORE 2' 'AL-MADINA STORE' 'ABDUL WAHEED K/S' '786 Sharif k/s'
#  'AHAMED K/S' 'ABDUL BAKI' 'AHAMED K/S' 'ARSHAD K.S' 'AKHTAR K/S'
#  'AHAMED K/S' 'ABDULLAH G/S' 'AL-MADINA STORE' 'AHAMED K/S' 'Asad K/S'
#  'AHAMED K/S' 'ASLAM GEN. STORE.' 'AHAMED K/S' 'AL Umair Store'
#  'AHAMED K/S' 'ALI WARIS K/S' 'Asad K/S' 'AHAMED K/S' 'AHAMED K/S'
#  'Al Madni K/S' 'AL Umair Store' 'Abid Cosmetic' 'AHAMED K/S'
#  'Al Madni K/S' 'AL-MADINA STORE' 'AL-MADINA STORE' 'AHAMED K/S'
#  'ASLAM GEN. STORE.' 'Al Madni K/S' 'AL-MADINA STORE' 'ABDUL WAHEED K/S'
#  'ABDULLAH G/S' 'ABDULLAH G/S' 'ASLAM GEN. STORE.' 'AL-MADINA STORE'
#  'AL-MADINA STORE' 'AL MADINA K/S' 'AL-MADINA STORE' 'AL-MADINA STORE'
#  'AHAMED K/S' '786 Bakery' 'AHAMED K/S' 'AFTAB St' 'ASLAM GEN. STORE.'
#  'AL AHMAD K/S' 'ASLAM GEN. STORE.' 'AHUJA M/S' 'ASLAM GEN. STORE.'
#  'Abid Cosmetic' 'ABDULLAH G/S' 'ASLAM GEN. STORE.' 'AL-MADINA STORE'
#  'AFTAB St' 'ARSHAD K.S' 'AHAMED K/S' 'AL-MADINA STORE' 'AL-MADINA STORE'
#  'AL-MADINA STORE' 'AL-MADINA STORE' 'ASLAM GEN. STORE.' 'Anayat K/s'
#  'AL-MADINA STORE' '786 Bakery' 'AL-MADINA STORE' 'AL-MADINA STORE'
#  'Aijaz Shaikh' 'AL-MADINA STORE' 'AL MADINA K/S' 'Asad K/S'
#  'AL MADINA K/S' 'AFRIDI' 'AL Umair Store' 'AHAMED K/S' 'Asad K/S'
#  'ALI WARIS K/S' 'AL-MADINA STORE' 'Asad K/S' 'AFTAB St' 'AL-MADINA STORE'
#  'AHUJA M/S' 'AL-MADINA STORE' 'ABDULLAH G/S' 'AL-MADINA STORE'
#  'A.M Traders' 'Asad K/S' 'AL MADINA K/S' 'AHAMED K/S' 'AMEET K/S'
#  'AHAMED K/S' 'AL MADINA K/S' 'ABDUL WAHEED K/S' 'Abid Cosmetic'
#  'AL-MADINA STORE' 'ASLAM GEN. STORE.' 'ASLAM GEN. STORE.' 'AHUJA M/S'
#  '786 Bakery' 'ASLAM GEN. STORE.' 'AHAMED K/S' 'ASLAM GEN. STORE.'
#  'Al Madni K/S' 'ABDULLAH G/S' 'AL-MADINA STORE' 'Asad K/S' '786 Bakery'
#  'Al Madni K/S' 'ABDUL WAHEED K/S' 'ASLAM GEN. STORE.' 'AMEET K/S'
#  'Abdul Karim Confectionary' 'AL Umair Store' 'AL MADINA K/S'
#  'AL MADINA K/S' 'AL Umair Store' 'AL-MADINA STORE' '786 Sharif k/s'
#  'ABDUL WAHEED K/S' 'AHAMED K/S' 'ASLAM GEN. STORE.' 'ARSHAD K.S'
#  'ASLAM GEN. STORE.' 'JHOLAYLAL' 'Al Madni K/S' 'ABDULLAH G/S'
#  'AHAMED K/S' 'AL-MADINA STORE' 'AL MADINA K/S' 'Aneel K/S' 'AHAMED K/S'
#  'AHAMED K/S' 'Al Madni K/S' 'AHAMED K/S' 'ARSHAD K.S' 'AMEET K/S'
#  'Dehleez K/S' 'AL Umair Store' 'AFRIDI' 'A ONE Masallah jat'
#  'AL-MADINA STORE' 'ABDULLAH G/S' 'ABDUL WAHEED K/S' 'AHAMED K/S'
#  'AL Umair Store' 'AL-MADINA STORE' 'ARSHAD K.S' 'ABDULLAH G/S'
#  'ASLAM GEN. STORE.' '786 K/S' 'AL-MADINA STORE' '786 Bakery'
#  'AL MADINA K/S' 'ASHRAF GS' 'ABDULLAH G/S' 'AHAMED K/S' 'Al Madni K/S'
#  'ALI WARIS K/S' 'Anayat K/s' 'AHUJA M/S' 'AL-MADINA STORE'
#  'AL-MADINA STORE' 'A.M Traders' 'AFRIDI' 'AFTAB St' 'AHAMED K/S'
#  'AL-MADINA STORE' 'AHMAD G/S' 'AHAMED K/S' 'ABDULLAH G/S'
#  'AL-MADINA STORE' 'ABDUL BAKI' 'AL-MADINA STORE' 'AL-MADINA STORE'
#  'AYAN STORE 2' 'AMEET K/S' 'AL-MADINA STORE' 'AHAMED K/S' 'AHAMED K/S'
#  'AL-MADINA STORE' 'AL Umair Store' 'Al Madni K/S' 'ABDULLAH G/S'
#  'AL MADINA K/S' 'AL-MADINA STORE' 'AHUJA M/S' 'AL-MADINA STORE'
#  'Al Madni K/S' 'BAQIR G/S' 'ASLAM GEN. STORE.' 'ARSHAD K.S'
#  'Al Madni K/S' 'AL-MADINA STORE' 'ABDULLAH G/S' 'AHAMED K/S' 'AHAMED K/S'
#  'AL-MADINA STORE' 'AL-MADINA STORE' 'ABDULLAH G/S' 'AL-MADINA STORE'
#  'ASLAM GEN. STORE.' 'AL-MADINA STORE' 'AL-MADINA STORE' 'AL-MADINA STORE'
#  'Asad K/S' 'AHAMED K/S' 'AL-MADINA STORE' 'AHAMED K/S' 'AL-MADINA STORE'
#  'Abdul Karim Confectionary' 'A ONE Masallah jat'
#  'Chaudhary Medical Store' 'Aalam Khan K.S' 'AL Umair Store'
#  'AYAN STORE 2' 'AL-MADINA STORE' 'ASLAM GEN. STORE.' 'AL-MADINA STORE'
#  'Aneel K/S' 'ABDUL WAHEED K/S' 'AL MADINA K/S' 'Qasim Cosmetics'
#  'Al Madni K/S' 'A.M Traders' 'AL Umair Store' 'Al Madni K/S' 'AFRIDI'
#  'AHAMED K/S' 'AL-MADINA STORE' 'AHAMED K/S' 'Al Madni K/S']
# Accuracy: 0.0016666666666666668
